# %% [markdown]
# <a href="https://colab.research.google.com/github/feitosaerica/Aula-09-09/blob/main/TrabalhoP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Orçamento com produtividade

v1 = float(input(" Digite a quantidade de metros:" ))

p1 = v1*8.5

if p1 <= 99.000:
  pp = p1 * 1
elif p1 > 100.000 and v1 <= 120.000:
  pp = p1 * 0.98
elif v1 > 120.000 and v1 <= 150.000:
  pp = p1 * 0.97
elif v1 > 150.000 and v1 <= 200.000:
  pp = p1 * 0.95
elif v1 > 200.000 and v1 <= 250.000:
  pp = p1 * 0.91
elif v1 >= 250.000:
  pp = p1 * 0.90
else:
  pp = p1 * 0.85

print(pp)
# Out:
#  Digite a quantidade kilos:250.000
# 1933.75

# %% [markdown]
# if comprimento <= 60 and largura <= 45:
#   tamanho = "PP"
# elif comprimento <= 65 and largura <= 48:
#   tamanho = "P"
# elif comprimento <= 70 and largura <= 51:
#   tamanho = "M"
# elif comprimento <= 75 and largura <= 54:
#   tamanho = "G"
# elif comprimento <= 80 and largura <= 57:
#   tamanho = "GG"
# else:
#   tamanho = "XGG"
