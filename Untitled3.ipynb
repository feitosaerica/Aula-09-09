# %% [markdown]
# <a href="https://colab.research.google.com/github/feitosaerica/Aula-09-09/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# for i

# %%
for i in range(1,10,2):
  print (i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
v1 = float(input("Digite valor 1:"))
v2 = float(input("Digite valor 2:"))
print(soma)

# %%
v1 = float(input("Digite valor 1:"))
v2 = float(input("Digite valor 2:"))
def funcaosoma(v1 + v2)
print(def funcaosoma)
# Out:
#   File "/tmp/ipykernel_3935/3554264903.py", line 3
#     def funcaosoma(v1:v2)
#                          ^
# SyntaxError: expected ':'

# %%
from math import pi, sin, radians
def Graus2Rad(Vg) :
  return Vg*pi/180

for i in range(0, 360, 5):
  Vr = radians(i)
  Seno = sin(Vr)
  print(f"Para angulo = {i} graus, seno ({i} = {Seno})")
# Out:
# Para angulo = 0 graus, seno (0 = 0.0)
# Para angulo = 5 graus, seno (5 = 0.08715574274765817)
# Para angulo = 10 graus, seno (10 = 0.17364817766693033)
# Para angulo = 15 graus, seno (15 = 0.25881904510252074)
# Para angulo = 20 graus, seno (20 = 0.3420201433256687)
# Para angulo = 25 graus, seno (25 = 0.42261826174069944)
# Para angulo = 30 graus, seno (30 = 0.49999999999999994)
# Para angulo = 35 graus, seno (35 = 0.573576436351046)
# Para angulo = 40 graus, seno (40 = 0.6427876096865393)
# Para angulo = 45 graus, seno (45 = 0.7071067811865475)
# Para angulo = 50 graus, seno (50 = 0.766044443118978)
# Para angulo = 55 graus, seno (55 = 0.8191520442889918)
# Para angulo = 60 graus, seno (60 = 0.8660254037844386)
# Para angulo = 65 graus, seno (65 = 0.9063077870366499)
# Para angulo = 70 graus, seno (70 = 0.9396926207859083)
# Para angulo = 75 graus, seno (75 = 0.9659258262890683)
# Para angulo = 80 graus, seno (80 = 0.984807753012208)
# ...

# %%
import math

# cabeçalho da tebela
print(f"{'Ângulo (graus)' :<15} {'Seno':<10}")

#Gera os valores dos ângulos de 0° a 360° com intervalos de 5°

for angulo in range(0, 361, 5):
  #converte o ângulo de graus para radianos
  radianos = math.radians(angulo)
  #Calcula o seno do ângulo
  seno = math.sin(radianos)
  #Exibe o ângulo e seu seno correspondente
  print(f"{angulo:<15} {seno:<10.4f}")
# Out:
# Ângulo (graus)  Seno
# 0               0.0000
# 5               0.0872
# 10              0.1736
# 15              0.2588
# 20              0.3420
# 25              0.4226
# 30              0.5000
# 35              0.5736
# 40              0.6428
# 45              0.7071
# 50              0.7660
# 55              0.8192
# 60              0.8660
# 65              0.9063
# 70              0.9397
# 75              0.9659
# 80              0.9848
# 85              0.9962
# 90              1.0000
# 95              0.9962
# 100             0.9848
# 105             0.9659
# 110             0.9397
# 115             0.9063
# 120             0.8660
# 125             0.8192
# 130             0.7660
# 135             0.7071
# 140             0.6428
# 145             0.5736
# 150             0.5000
# 155             0.4226
# 160             0.3420
# 165             0.2588
# 170             0.1736
# 175             0.0872
# 180             0.0000
# 185             -0.0872
# 190             -0.1736
# ...

# %%
# Solicita ao usuário que insira a quantidade de alunos
n = int(input("Digite a quantidade de alunos: "))

# Inicializa a variável para armazenar a soma das médias
somasdasmedias = 0

# Laço para calcular a média de cada aluno
for i in range (1, n + 1):
  print(f"\nAluno {i}:")
  n1 = float(input("Digite a nota N1: "))
  n2 = float(input("Digite a nota N2: "))

  # Calcula a média do aluno
  media = (n1 + n2) / 2
# Out:
# Digite a quantidade de alunos: 2
#
# Aluno 1:
# Digite a nota N1: 80
# Digite a nota N2: 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3935/1003164463.py in <cell line: 0>()
#      12
#      13   # Calcula a média do aluno
# ---> 14   print(media = (n1 + n2) / 2)
#
# TypeError: print() got an unexpected keyword argument 'media'

# %%
resp = input("Deseja calcular? (S=SIM, N=Não)")

while resp == "S":
    v1 = float(input("Digite valor 1:"))
    v2 = float(input("Digite valor 2:"))
    m = (v1+v2)/2
    print(f"A média é {m}")
    resp = input("Deseja calcular? (S=SIM, N=Não)")
    print("Ok,até logo! Obrigada por me executar!")
# Out:
# Deseja calcular? (S=SIM, N=Não)S
# Digite valor 1:390
# Digite valor 2:290
# A média é 340.0
# Deseja calcular? (S=SIM, N=Não)S
# Ok,até logo! Obrigada por me executar!
# Digite valor 1:490
# Digite valor 2:109
# A média é 299.5
# Deseja calcular? (S=SIM, N=Não)N
# Ok,até logo! Obrigada por me executar!
